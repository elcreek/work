# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

import time

from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By



options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

options.binary_location = "C:\Program Files\BraveSoftware\Brave-Browser\Application\\brave.exe"
chrome_driver_binary = "C:\webdrivers\chromedriver.exe"
# driver = webdriver.Chrome(chrome_driver_binary, chrome_options=options)


# options = Options()

site = 'https://coinmarketcap.com/exchanges/binance/' 

# b = webdriver.Chrome('chromedriver',options=options)
b = webdriver.Chrome(chrome_driver_binary,options=options)

# b = webdriver.Chrome(options=options)

b.get(site)

# # b.find_elements_by_class_name("x0o17e-0 DChGS sc-1xafy60-11 cjuuEm")
# # b.find_elements(by=By.CLASS_NAME, value="x0o17e-0 DChGS sc-1xafy60-11 cjuuEm")
# # b.find_element_by_xpath("//Button[@class='x0o17e-0 DChGS sc-1xafy60-11 cjuuEm']")
# btn = b.find_element(by=By.XPATH, value="//Button[@class='x0o17e-0 DChGS sc-1xafy60-11 cjuuEm']")
# b.execute_script("arguments[0].click();", btn)
# # b.find_element_by_xpath("//div[@class='x0o17e-0 DChGS sc-1xafy60-11 cjuuEm']")
# # "//button[contains(., 'Load More Results')]"

while True:
  time.sleep(1)
  try:
    # btn.click()
    btn = b.find_element(by=By.XPATH, value="//Button[@class='x0o17e-0 DChGS sc-1xafy60-11 cjuuEm']")
    b.execute_script("arguments[0].click();", btn)
    print(0)
  except NoSuchElementException:
    break


html = b.page_source

df = pd.read_html(html)

df[0].to_csv('data.csv')


# from google.colab import files
# files.download("data.csv")
