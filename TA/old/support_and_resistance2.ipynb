# %%
# the subbort that had a major move will be considerred more reliable
# same for resistance

# %%
import pandas as pd
import numpy as np
# import yfinance

# from mplfinance import candlestick_ohlc
from mplfinance.original_flavor import candlestick_ohlc

import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt
import os
import plotly.graph_objects as go

from datetime import datetime

from scipy.signal import argrelextrema


# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# plt.rcParams['figure.figsize'] = [12, 7]

# plt.rc('font', size=14)

# %%
name = 'BTC-USD'
df=pd.read_csv("C:\\Users\Grant\Desktop\work_git\work\data\\1d\ETCUSDT_1d.csv",index_col=['Time'], parse_dates=['Time'])


# ticker = yfinance.Ticker(name)
# df = ticker.history(interval="90m")

# # df = ticker.history(interval="1d",start="2020-03-15",end="2020-07-15")



# df = df.reset_index().set_index('Time') # SWITCH INDEX AND TIME COLumn places

# df = df.set_index('Time')

# df['Date'] = df['Time']
# pd.to_datetime(df['Time'])
# pd.to_datetime(df['Date'])
# df = df.set_index('Time')

# %%
# df

# %%
df['Date'] = pd.to_datetime(df.index)
# change datetime into matplotlib time
# does not work with plotly
# df['Date'] = df['Date'].apply(mpl_dates.date2num)

df = df.loc[:,['Date' ,'Open', 'High', 'Low', 'Close']]

# %%
# df

# %%
# def isSupport(df,i):
#   # fractal (i-2)>(i-1)>i<(i+1)<(i+2)
#   # support = df['Low'][i] < df['Low'][i-1]  and df['Low'][i] < df['Low'][i+1] \
#   # and df['Low'][i+1] < df['Low'][i+2] and df['Low'][i-1] < df['Low'][i-2]

#   support = df['Close'][i] < df['Close'][i-1]  and df['Close'][i] < df['Close'][i+1] \
#   and df['Close'][i+1] < df['Close'][i+2] and df['Close'][i-1] < df['Close'][i-2]

#   return support

# def isResistance(df,i):
#   # resistance = df['High'][i] > df['High'][i-1]  and df['High'][i] > df['High'][i+1] \
#   # and df['High'][i+1] > df['High'][i+2] and df['High'][i-1] > df['High'][i-2] 

#   resistance = df['Close'][i] > df['Close'][i-1]  and df['Close'][i] > df['Close'][i+1] \
#   and df['Close'][i+1] > df['Close'][i+2] and df['Close'][i-1] > df['Close'][i-2] 

#   return resistance

# %%
# def isSupport(df,i):
support = (argrelextrema(df['Close'].values, np.less, order=5)[0]).tolist()
levels_s = (df['Close'][support].values).tolist()

    # return levels_s

# def isResistance(df,i):
resistance = (argrelextrema(df['Close'].values, np.greater, order=5)[0]).tolist()
# levels_r = (df.iloc[resistance]['Close'].values).tolist()
levels_r = (df['Close'][resistance].values).tolist()

    # return levels_r

# %%
# levels = []
# # start from 2 because i need i-2
# # end at shape[0]-2 because  i need i+2
# # i is the number of current row
# for i in range(2,df.shape[0]-2):
#   if isSupport(df,i):
#     levels.append((i,df['Low'][i]))
#   elif isResistance(df,i):
#     levels.append((i,df['High'][i]))

# %%
# levels = []
# # start from 2 because i need i-2
# # end at shape[0]-2 because  i need i+2
# # i is the number of current row
# for i in range(2,df.shape[0]-2):
#   if isSupport(df,i):
#     levels.append((i,df['Close'][i]))
#   elif isResistance(df,i):
#     levels.append((i,df['Close'][i]))

# %%
import itertools
l2=set()
levels = levels_r #+ levels_s
for i in range(len(levels)):
    for j in range(i + 1, len(levels)-1):
        if (levels[i] < levels[j] and levels[j] < (levels[i] + 0.1*levels[i]))\
            or  (levels[i] > levels[j] and levels[j] > (levels[i] - 0.1*levels[i])):
            # print(levels[i])
            l2.add(levels[i])
            # levels.remove(levels[i])

# levels.remove(l2[-1])
# levels
for l in l2:
    levels.remove(l)

# l2
levels
# l2
# l
# Out:
# [3.8977,
#  12.2074,
#  5.3597,
#  5.9188,
#  8.8346,
#  7.9,
#  15.669,
#  13.7733,
#  133.864,
#  73.54,
#  60.85,
#  35.41,
#  32.84]

# %%
# MOCHLV = zip(df.Date, df.Open, df.Close, df.High, df.Low, df.Volume)

# %%
# def plot_all():
#   fig, ax = plt.subplots()

#   candlestick_ohlc(ax,df.values,width=0.6, \
#                    colorup='green', colordown='red', alpha=0.8)
#   # candlestick_ohlc(ax,MOCHLV)

#   date_format = mpl_dates.DateFormatter('%d %b %Y')
#   ax.xaxis.set_major_formatter(date_format)
#   fig.autofmt_xdate()

#   fig.tight_layout()

#   for level in levels:
#     plt.hlines(level[1],xmin=df['Date'][level[0]],\
#                xmax=max(df['Date']),colors='blue')
#   fig.show()

# %%
# def plot_all():

    # fig = go.Figure(data=[go.Candlestick(x=df['Date'],
    #             open=df['Open'],
    #             high=df['High'],
    #             low=df['Low'],
    #             close=df['Close'])])

    # for level in levels:
    #     # fig.add_hline(level[1])
    #     fig.add_shape(type='line',
    #             x0=df['Date'][level[0]],
    #             y0=level[1],
    #             x1=max(df['Date']),
    #             y1=level[1],
    #             line=dict(color='black',),
    #             xref='x',
    #             yref='y')
    
    # fig.layout.xaxis.rangeslider.visible = False


    # fig.show()

def plot_all(df):

    candlestick = go.Candlestick(x=df.index, open=df['Open'], high=df['High'], low=df['Low'], close=df['Close'])

    # fig = go.Figure(data=[go.Candlestick(x=df['Date'],
    #             open=df['Open'],
    #             high=df['High'],
    #             low=df['Low'],
    #             close=df['Close'])])
    fig = go.Figure(data=candlestick)
    for level in levels:
        fig.add_hline(level)

    # for level in levels:
    #     fig.add_shape(type='line',
    #             x0=df['Date'][level[0]],
    #             y0=level[1],
    #             x1=max(df['Date']),
    #             y1=level[1],
    #             line=dict(color='black',),
    #             xref='x',
    #             yref='y')
    
    fig.layout.xaxis.rangeslider.visible = False


    fig.show()



#   fig, ax = plt.subplots()

#   candlestick_ohlc(ax,df.values,width=0.6, \
#                    colorup='green', colordown='red', alpha=0.8)
#   # candlestick_ohlc(ax,MOCHLV)

#   date_format = mpl_dates.DateFormatter('%d %b %Y')
#   ax.xaxis.set_major_formatter(date_format)
#   fig.autofmt_xdate()

#   fig.tight_layout()

#   for level in levels:
#     plt.hlines(level[1],xmin=df['Date'][level[0]],\
#                xmax=max(df['Date']),colors='blue')
#   fig.show()

# %%
# plot_all()

# %%
# s =  np.mean(df['High'] - df['Low'])

# %%
# def isFarFromLevel(l):
#   return np.sum([abs(l-x) < s  for x in levels]) == 0

# %%
# levels = []
# for i in range(2,df.shape[0]-2):
#   if isSupport(df,i):
#     l = df['Low'][i]

#     if isFarFromLevel(l):
#       levels.append((i,l))

#   elif isResistance(df,i):
#     l = df['High'][i]

#     if isFarFromLevel(l):
#       levels.append((i,l))

# %%
levels
# Out:
# [3.8977,
#  12.2074,
#  5.3597,
#  5.9188,
#  8.8346,
#  7.9,
#  15.669,
#  13.7733,
#  133.864,
#  73.54,
#  60.85,
#  35.41,
#  32.84]

# %%
plot_all(df)

# %%
for level in levels:
    if (df['Close'][-2] < level[1]) and (df['Close'][-1] > level[1]):
        print(level[1] + 'breakout')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Grant\Desktop\work_git\work\support_and_resistance2.ipynb Cell 23' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Grant/Desktop/work_git/work/support_and_resistance2.ipynb#ch0000019?line=0'>1</a> for level in levels:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Grant/Desktop/work_git/work/support_and_resistance2.ipynb#ch0000019?line=1'>2</a>     if (df['Close'][-2] < level[1]) and (df['Close'][-1] > level[1]):
#       <a href='vscode-notebook-cell:/c%3A/Users/Grant/Desktop/work_git/work/support_and_resistance2.ipynb#ch0000019?line=2'>3</a>         print(level[1] + 'breakout')
#
# TypeError: 'float' object is not subscriptable
