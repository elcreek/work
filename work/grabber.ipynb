# %%
from datetime import datetime
import os
from time import time
from typing import ClassVar
import yfinance as yf
import pandas as pd
from flask import Flask, render_template
from patterns import patterns
import tqdm
from binance import Client
import time
from datetime import datetime
import datetime

from csv import writer



api_key = ''
api_secret = ''

client = Client(api_key, api_secret)

# %%
klines = client.get_historical_klines("ETHBTC", Client.KLINE_INTERVAL_1MINUTE, "1 Dec, 2021")
df = pd.DataFrame(klines)
df.to_csv("ETHBTC.csv")

# %%
# screener_parttime_larry

# def update_csv():
#     loop over all csv
#     get last row unix time
#     convert it to datetime
#     use get historical kline 
#     append to old Csv


# if unix_time_today != last_row_unix_time:
#     call update_csv

# import required module

# assign directory
directory = 'C:/Users/Grant/virenv/screener_parttime_larry/datasets/daily'
 
df = pd.read_csv("C:/Users/Grant/virenv/screener_parttime_larry/datasets/daily/ETHBTC.csv")
last_unix = df.tail(1)['0'].values
last_unix = pd.to_datetime(last_unix,unit='ms', )
last_unix = str(last_unix[0])
date = last_unix[0:11]
# print(last_unix)

# iterate over files in
# that directory
# def get(date):
#     for filename in os.listdir(directory):
#         f = os.path.join(directory, filename)
#         # checking if it is a file
#         if os.path.isfile(f):
#             # print(f)
#             with open(f,'a',newline='\n') as f:
#                 file_name = filename[:-4]
#                 writer_object = writer(f)
#                 # print(file_name)
#                 # klines=client.get_historical_klines(file_name, Client.KLINE_INTERVAL_1MINUTE, date)
#                 df = pd.DataFrame(client.get_historical_klines(file_name, Client.KLINE_INTERVAL_1MINUTE, date))
#                 writer_object.writerow(df)
#                 # print(filename)
#                 # print(type(filename))

# get(date)

def gee(date):
    with open('C:/Users/Grant/virenv/screener_parttime_larry/datasets/tickers.csv') as f:
        symbols = f.read().splitlines()
        for symbol in symbols:
            klines = client.get_historical_klines(symbol, Client.KLINE_INTERVAL_1MINUTE, date)
            df = pd.DataFrame(klines)
            df.to_csv("datasets\daily\{}.csv".format(symbol+"_"+date))



# last_unix = last_unix.astype(int)
# print(type(last_unix))
# today = datetime.date.today()


# today = pd.to_datetime(time_now,unit='ms', )
# print(today)

# now = datetime.now()
# current_time = now.strftime("%Y-%m-%d")

# print(last_unix.strftime('%Y-%m-%d'))
# print(last_unix)
# last_unix= int(last_unix)
# print(datetime.utcfromtimestamp(last_unix).strftime('%Y-%m-%d'))

# value = datetime.datetime.fromtimestamp(last_unix)
# print(f"{value:%Y-%m-%d %H:%M:%S}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8240/2942318848.py in <module>
#      42                 # print(type(filename))
#      43
# ---> 44 get(date)
#      45
#      46 # def gee(date):
#
# ~\AppData\Local\Temp/ipykernel_8240/2942318848.py in get(date)
#      37                 # print(file_name)
#      38                 # klines=client.get_historical_klines(file_name, Client.KLINE_INTERVAL_1MINUTE, date)
# ---> 39                 df = pd.DataFrame(client.get_historical_klines(file_name, Client.KLINE_INTERVAL_1MINUTE, date))
#      40                 writer_object.writerow(df)
#      41                 # print(filename)
#
# c:\Users\Grant\virenv\fintech\lib\site-packages\binance\client.py in get_historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#     930
#     931         """
# ...
